# %% [markdown]
# ### Vue satellite simple avec couleurs D+

# %%
import folium
import gpxpy
import glob
import pandas as pd
import matplotlib.colors as colors
import os
import math

# -------------------------------
# 1. Paramètres globaux
# -------------------------------
center_lat = 46
center_lon = 8
zoom_start = 7.1

# -------------------------------
# 2. Définition des voyages
# -------------------------------
voyages = {
    "2025_Montpellier-Munich": {
        "folder": "gpx/2025_Montpellier-Munich",
        "type": "palette",
        "colors": ["#FFD000", "#FF0000"],  # Jaune -> Rouge
        "legend": {
            "Trip name": "Montpellier-Munich",
            "Date": "July-August 2025",
            "Distance": "2200 km",
            "Total D+": "16000 m"
        }
    },

    "2024_Alsace-Paris": {
        "folder": "gpx/2024_Alsace-Paris",
        "type": "fixed",
        "color": "#FFA500",  # Orange fixe
        "legend": {
            "Trip name": "Alsace-Paris",
            "Date": "April 2024",
            "Distance": "XXX km",
            "Total D+": "XXX m"
        }
    },

    "2024_Orléans-Bourgogne": {
        "folder": "gpx/2023_Orleans-Bourgogne",
        "type": "fixed",
        "color": "#FFA500",  # Orange fixe
        "legend": {
            "Trip name": "Orléans-Bourgogne",
            "Date": "July 2023",
            "Distance": "345 km",
            "Total D+": "3000 m"
        }
    }
}

# -------------------------------
# 3. Créer la carte
# -------------------------------
m = folium.Map(location=[center_lat, center_lon], zoom_start=zoom_start, tiles=None)
folium.TileLayer(
    tiles="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}",
    attr='Tiles © Esri',
    name="ESRI Satellite",
    overlay=False,
    control=True
).add_to(m)

# -------------------------------
# 4. Tracer les GPX avec popup + tooltip (complète)
# -------------------------------
for voyage_name, params in voyages.items():
    folder = params["folder"]
    gpx_files = glob.glob(os.path.join(folder, "*.gpx"))

    # HTML complet de la légende pour tooltip et popup
    legend = params.get("legend", {})
    legend_html = f"""
    <div style="
        background-color: rgba(0,0,0,0.6); 
        color: white; 
        padding: 8px; 
        border-radius: 8px; 
        font-size: 14px; 
        font-weight: bold;
        text-shadow: 1px 1px 2px black;">
        Trip name: {legend.get('Trip name','')}<br>
        Date: {legend.get('Date','')}<br>
        Distance: {legend.get('Distance','')}<br>
        Total D+: {legend.get('Total D+','')}
    </div>
    """

    if params["type"] == "palette":
        txt_path = os.path.join(folder, "D+.txt")
        df = pd.read_csv(txt_path, sep="\t", header=None)
        df = df.rename(columns={0: "GPX", 3: "Difficulte"})
        df["GPX"] = df["GPX"].astype(int)

        cmap = colors.LinearSegmentedColormap.from_list("yellow_red", params["colors"])
        norm = colors.Normalize(vmin=df["Difficulte"].min(), vmax=df["Difficulte"].max())

        def get_color(val):
            rgba = cmap(norm(val))
            return colors.to_hex(rgba)

        for gpx_file in gpx_files:
            filename = os.path.basename(gpx_file)
            try:
                gpx_num = int(os.path.splitext(filename)[0])
                difficulte = df.loc[df["GPX"] == gpx_num, "Difficulte"].values[0]
                color = get_color(difficulte)
            except Exception:
                color = "#FFD000"

            with open(gpx_file, 'r', encoding='utf-8') as f:
                gpx = gpxpy.parse(f)
                for track in gpx.tracks:
                    for segment in track.segments:
                        points = [(p.latitude, p.longitude) for p in segment.points]
                        if points:
                            folium.PolyLine(
                                points,
                                color=color,
                                weight=4,
                                opacity=0.9,
                                popup=folium.Popup(legend_html, max_width=300),
                                tooltip=legend_html
                            ).add_to(m)

    elif params["type"] == "fixed":
        color = params["color"]
        for gpx_file in gpx_files:
            with open(gpx_file, 'r', encoding='utf-8') as f:
                gpx = gpxpy.parse(f)
                for track in gpx.tracks:
                    for segment in track.segments:
                        points = [(p.latitude, p.longitude) for p in segment.points]
                        if points:
                            folium.PolyLine(
                                points,
                                color=color,
                                weight=4,
                                opacity=0.9,
                                popup=folium.Popup(legend_html, max_width=300),
                                tooltip=legend_html
                            ).add_to(m)

# -------------------------------
# 5. Villes principales / secondaires avec offsets et zoom dynamique
# -------------------------------
villes = {
    "Paris": (48.8566, 2.3522),
    "Montpellier": (43.6119, 3.8772),
    "Venezia": (45.4408, 12.3155),
    "Marseille": (43.2965, 5.3698),
    "Toulon": (43.1242, 5.9280),
    "Cannes": (43.5528, 7.0174),
    "Nice": (43.7102, 7.2620),
    "Firenze": (43.7696, 11.2558),
    "Bologna": (44.4949, 11.3426),
    "Salzburg": (47.8095, 13.0550),
    "Villach": (46.6167, 13.8500),
    "Genova": (44.4056, 8.9463),
    "Lucca": (43.8429, 10.5027),
    "Udine": (46.0620, 13.2340),
    "München": (48.1351, 11.5820),
    "Roma": (41.9028, 12.4964),
    "Rapallo": (44.3500, 9.2330),
    "Strasbourg": (48.5839, 7.7455),
    "Gérardmer": (48.0727, 6.8990),
    "Troyes": (48.2973, 4.0744),
    "Gien": (47.6178, 2.5863),
    "Nevers": (46.9896, 3.1590),
    "Paray-le-Monial": (46.3785, 4.0664),
    "Bezornay": (46.4835, 4.5710),
    "Orléans": (47.9025, 1.9090)
}

# Catégorisation
villes_principales = ["Paris", "Montpellier", "München", "Roma", "Strasbourg"]
villes_secondaires = [v for v in villes if v not in villes_principales]

# Offsets
proximity_thresh = 0.5
base_offset = 8
max_offset = 10
zoom_factor = 1.2
def haversine(lat1, lon1, lat2, lon2):
    return math.sqrt((lat1 - lat2)**2 + (lon1 - lon2)**2)

offsets = {nom: (base_offset, -base_offset) for nom in villes.keys()}
noms = list(villes.keys())
for i in range(len(noms)):
    for j in range(i+1, len(noms)):
        city1, city2 = noms[i], noms[j]
        lat1, lon1 = villes[city1]
        lat2, lon2 = villes[city2]
        dist = haversine(lat1, lon1, lat2, lon2)
        if dist < proximity_thresh:
            offset_val = min(max_offset, (proximity_thresh - dist) / proximity_thresh * max_offset)
            dx = offset_val * zoom_factor
            dy = offset_val * zoom_factor
            offsets[city1] = (-dx, -dy)
            offsets[city2] = (dx, dy)

# -------------------------------
# Villes principales
# -------------------------------
fg_principales = folium.FeatureGroup(name="Villes principales")
for nom in villes_principales:
    coord = villes[nom]
    folium.CircleMarker(
        location=coord,
        radius=4,
        color='white',
        fill=True,
        fill_color='blue',
        fill_opacity=0.9
    ).add_to(fg_principales)
    dx, dy = offsets[nom]
    folium.map.Marker(
        location=coord,
        icon=folium.DivIcon(
            icon_size=(150, 36),
            icon_anchor=(0, 0),
            html=f"""<div style="font-size:14px; color:white; font-weight:bold;
                        text-shadow:1px 1px 2px black;
                        transform: translate({dx}px, {dy}px);">{nom}</div>"""
        )
    ).add_to(fg_principales)
fg_principales.add_to(m)

# -------------------------------
# Villes secondaires (zoom ≥ 8)
# -------------------------------
fg_secondaires = folium.FeatureGroup(name="Villes secondaires")
for nom in villes_secondaires:
    coord = villes[nom]
    folium.CircleMarker(
        location=coord,
        radius=3,
        color='white',
        fill=True,
        fill_color='green',
        fill_opacity=0.8
    ).add_to(fg_secondaires)
    dx, dy = offsets[nom]
    folium.map.Marker(
        location=coord,
        icon=folium.DivIcon(
            icon_size=(150, 36),
            icon_anchor=(0, 0),
            html=f"""<div style="font-size:12px; color:white; font-weight:bold;
                        text-shadow:1px 1
px 2px 2px black;
                        transform: translate({dx}px, {dy}px);">{nom}</div>"""
        )
    ).add_to(fg_secondaires)
fg_secondaires.add_to(m)

# -------------------------------
# Contrôle de calques
# -------------------------------
folium.LayerControl().add_to(m)

# -------------------------------
# JS pour afficher secondaires uniquement à zoom ≥ 8
# -------------------------------
js = f"""
var secondairesLayer = {fg_secondaires.get_name()};
function setSecondaryVisibility(){{
    var zoom = map.getZoom();
    if(zoom < 8){{
        map.removeLayer(secondairesLayer);
    }} else {{
        map.addLayer(secondairesLayer);
    }}
}}
map.on('zoomend', setSecondaryVisibility);
setSecondaryVisibility();
"""
m.get_root().html.add_child(folium.Element(f'<script>{js}</script>'))

# -------------------------------
# 6. Sauvegarder
# -------------------------------
output_file = "index.html"
m.save(output_file)
print(f"✅ Carte générée : {output_file}")
# Out:
# ✅ Carte générée : index.html

# %% [markdown]
# ### Backup

# %%
import folium
import gpxpy
import glob
import pandas as pd
import matplotlib.colors as colors
import os
import math

# -------------------------------
# 1. Paramètres globaux
# -------------------------------
center_lat = 46
center_lon = 8
zoom_start = 7.1

# -------------------------------
# 2. Définition des voyages
# -------------------------------
voyages = {
    "2025_Montpellier-Munich": {
        "folder": "gpx/2025_Montpellier-Munich",
        "type": "palette",
        "colors": ["#FFD000", "#FF0000"],  # Jaune -> Rouge
        "legend": {
            "Trip name": "Montpellier-Munich",
            "Date": "July-August 2025",
            "Distance": "2200 km",
            "Total D+": "16000 m"
        }
    },
    "2024_Alsace-Paris": {
        "folder": "gpx/2024_Alsace-Paris",
        "type": "fixed",
        "color": "#FFA500",  # Orange fixe
        "legend": {
            "Trip name": "Alsace-Paris",
            "Date": "2024",
            "Distance": "XXX km",
            "Total D+": "XXX m"
        }
    }
}

# -------------------------------
# 3. Créer la carte
# -------------------------------
m = folium.Map(location=[center_lat, center_lon], zoom_start=zoom_start, tiles=None)
folium.TileLayer(
    tiles="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}",
    attr='Tiles © Esri',
    name="ESRI Satellite",
    overlay=False,
    control=True
).add_to(m)

# -------------------------------
# 4. Tracer les GPX avec popup + tooltip (complète)
# -------------------------------
for voyage_name, params in voyages.items():
    folder = params["folder"]
    gpx_files = glob.glob(os.path.join(folder, "*.gpx"))

    # HTML complet de la légende pour tooltip et popup
    legend = params.get("legend", {})
    legend_html = f"""
    <div style="
        background-color: rgba(0,0,0,0.6); 
        color: white; 
        padding: 8px; 
        border-radius: 8px; 
        font-size: 14px; 
        font-weight: bold;
        text-shadow: 1px 1px 2px black;">
        Trip name: {legend.get('Trip name','')}<br>
        Date: {legend.get('Date','')}<br>
        Distance: {legend.get('Distance','')}<br>
        Total D+: {legend.get('Total D+','')}
    </div>
    """

    if params["type"] == "palette":
        txt_path = os.path.join(folder, "D+.txt")
        df = pd.read_csv(txt_path, sep="\t", header=None)
        df = df.rename(columns={0: "GPX", 3: "Difficulte"})
        df["GPX"] = df["GPX"].astype(int)

        cmap = colors.LinearSegmentedColormap.from_list("yellow_red", params["colors"])
        norm = colors.Normalize(vmin=df["Difficulte"].min(), vmax=df["Difficulte"].max())

        def get_color(val):
            rgba = cmap(norm(val))
            return colors.to_hex(rgba)

        for gpx_file in gpx_files:
            filename = os.path.basename(gpx_file)
            try:
                gpx_num = int(os.path.splitext(filename)[0])
                difficulte = df.loc[df["GPX"] == gpx_num, "Difficulte"].values[0]
                color = get_color(difficulte)
            except Exception:
                color = "#FFD000"

            with open(gpx_file, 'r', encoding='utf-8') as f:
                gpx = gpxpy.parse(f)
                for track in gpx.tracks:
                    for segment in track.segments:
                        points = [(p.latitude, p.longitude) for p in segment.points]
                        if points:
                            folium.PolyLine(
                                points,
                                color=color,
                                weight=4,
                                opacity=0.9,
                                popup=folium.Popup(legend_html, max_width=300),
                                tooltip=legend_html
                            ).add_to(m)

    elif params["type"] == "fixed":
        color = params["color"]
        for gpx_file in gpx_files:
            with open(gpx_file, 'r', encoding='utf-8') as f:
                gpx = gpxpy.parse(f)
                for track in gpx.tracks:
                    for segment in track.segments:
                        points = [(p.latitude, p.longitude) for p in segment.points]
                        if points:
                            folium.PolyLine(
                                points,
                                color=color,
                                weight=4,
                                opacity=0.9,
                                popup=folium.Popup(legend_html, max_width=300),
                                tooltip=legend_html
                            ).add_to(m)

# -------------------------------
# 5. Villes avec offset léger et ajustement pour proches
# -------------------------------
villes = {
    "Paris": (48.8566, 2.3522),
    "Montpellier": (43.6119, 3.8772),
    "Venezia": (45.4408, 12.3155),
    "Marseille": (43.2965, 5.3698),
    "Toulon": (43.1242, 5.9280),
    "Cannes": (43.5528, 7.0174),
    "Nice": (43.7102, 7.2620),
    "Firenze": (43.7696, 11.2558),
    "Bologna": (44.4949, 11.3426),
    "Salzburg": (47.8095, 13.0550),
    "Villach": (46.6167, 13.8500),
    "Genova": (44.4056, 8.9463),
    "Lucca": (43.8429, 10.5027),
    "Udine": (46.0620, 13.2340),
    "München": (48.1351, 11.5820),
    "Roma": (41.9028, 12.4964),
    "Rapallo": (44.3500, 9.2330),
    "Strasbourg": (48.5839, 7.7455),
    "Gérardmer": (48.0727, 6.8990),
    "Troyes": (48.2973, 4.0744)
}

proximity_thresh = 0.5
base_offset = 8
max_offset = 10
zoom_factor = 1.2

def haversine(lat1, lon1, lat2, lon2):
    return math.sqrt((lat1 - lat2)**2 + (lon1 - lon2)**2)

offsets = {nom: (base_offset, -base_offset) for nom in villes.keys()}
noms = list(villes.keys())
for i in range(len(noms)):
    for j in range(i+1, len(noms)):
        city1, city2 = noms[i], noms[j]
        lat1, lon1 = villes[city1]
        lat2, lon2 = villes[city2]
        dist = haversine(lat1, lon1, lat2, lon2)
        if dist < proximity_thresh:
            offset_val = min(max_offset, (proximity_thresh - dist) / proximity_thresh * max_offset)
            dx = offset_val * zoom_factor
            dy = offset_val * zoom_factor
            offsets[city1] = (-dx, -dy)
            offsets[city2] = (dx, dy)

for nom, coord in villes.items():
    folium.CircleMarker(
        location=coord,
        radius=4,
        color='white',
        fill=True,
        fill_color='blue',
        fill_opacity=0.9
    ).add_to(m)

    dx, dy = offsets[nom]
    folium.map.Marker(
        location=coord,
        icon=folium.DivIcon(
            icon_size=(150, 36),
            icon_anchor=(0, 0),
            html=f"""<div style="font-size:14px; color:white; font-weight:bold;
                        text-shadow:1px 1px 2px black;
                        transform: translate({dx}px, {dy}px);">{nom}</div>"""
        )
    ).add_to(m)

# -------------------------------
# 6. Sauvegarder
# -------------------------------
output_file = "index.html"
m.save(output_file)
print(f"✅ Carte générée : {output_file}")
# Out:
# ✅ Carte générée : index.html

# %% [markdown]
# ### Perplex

# %%
import folium
import gpxpy
import glob
import pandas as pd
import matplotlib.colors as colors
import os
import math
from branca.element import MacroElement
from jinja2 import Template

# -------------------------------
# 1. Paramètres globaux
# -------------------------------
center_lat = 46
center_lon = 8
zoom_start = 7.1

# -------------------------------
# 2. Définition des voyages
# -------------------------------
voyages = {
    "2025_Montpellier-Munich": {
        "folder": "gpx/2025_Montpellier-Munich",
        "type": "palette",
        "colors": ["#FFD000", "#FF0000"],  # Jaune -> Rouge
        "legend": {
            "Trip name": "Montpellier-Munich",
            "Date": "July-August 2025",
            "Distance": "2200 km",
            "Total D+": "16000 m"
        }
    },
    "2024_Alsace-Paris": {
        "folder": "gpx/2024_Alsace-Paris",
        "type": "fixed",
        "color": "#FFA500",  # Orange fixe
        "legend": {
            "Trip name": "Alsace-Paris",
            "Date": "2024",
            "Distance": "XXX km",
            "Total D+": "XXX m"
        }
    }
}

# -------------------------------
# 3. Créer la carte
# -------------------------------
m = folium.Map(location=[center_lat, center_lon], zoom_start=zoom_start, tiles=None)
folium.TileLayer(
    tiles="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}",
    attr='Tiles © Esri',
    name="ESRI Satellite",
    overlay=False,
    control=True
).add_to(m)

# -------------------------------
# 4. Tracer les GPX avec popup + tooltip (complète)
# -------------------------------
for voyage_name, params in voyages.items():
    folder = params["folder"]
    gpx_files = glob.glob(os.path.join(folder, "*.gpx"))

    legend = params.get("legend", {})
    legend_html = f"""
    <div style="
    background-color: rgba(0,0,0,0.6);
    color: white;
    padding: 8px;
    border-radius: 8px;
    font-size: 14px;
    font-weight: bold;
    text-shadow: 1px 1px 2px black;">
    Trip name: {legend.get('Trip name','')}<br>
    Date: {legend.get('Date','')}<br>
    Distance: {legend.get('Distance','')}<br>
    Total D+: {legend.get('Total D+','')}
    </div>
    """

    if params["type"] == "palette":
        txt_path = os.path.join(folder, "D+.txt")
        df = pd.read_csv(txt_path, sep="\t", header=None)
        df = df.rename(columns={0: "GPX", 3: "Difficulte"})
        df["GPX"] = df["GPX"].astype(int)

        cmap = colors.LinearSegmentedColormap.from_list("yellow_red", params["colors"])
        norm = colors.Normalize(vmin=df["Difficulte"].min(), vmax=df["Difficulte"].max())

        def get_color(val):
            rgba = cmap(norm(val))
            return colors.to_hex(rgba)

        for gpx_file in gpx_files:
            filename = os.path.basename(gpx_file)
            try:
                gpx_num = int(os.path.splitext(filename)[0])
                difficulte = df.loc[df["GPX"] == gpx_num, "Difficulte"].values[0]
                color = get_color(difficulte)
            except Exception:
                color = "#FFD000"

            with open(gpx_file, 'r', encoding='utf-8') as f:
                gpx = gpxpy.parse(f)
                for track in gpx.tracks:
                    for segment in track.segments:
                        points = [(p.latitude, p.longitude) for p in segment.points]
                        if points:
                            folium.PolyLine(
                                points,
                                color=color,
                                weight=4,
                                opacity=0.9,
                                popup=folium.Popup(legend_html, max_width=300),
                                tooltip=legend_html
                            ).add_to(m)

    elif params["type"] == "fixed":
        color = params["color"]
        for gpx_file in gpx_files:
            with open(gpx_file, 'r', encoding='utf-8') as f:
                gpx = gpxpy.parse(f)
                for track in gpx.tracks:
                    for segment in track.segments:
                        points = [(p.latitude, p.longitude) for p in segment.points]
                        if points:
                            folium.PolyLine(
                                points,
                                color=color,
                                weight=4,
                                opacity=0.9,
                                popup=folium.Popup(legend_html, max_width=300),
                                tooltip=legend_html
                            ).add_to(m)

# -------------------------------
# 5. Villes primaires et secondaires avec gestion zoom
# -------------------------------
villes_primaires = {
    "Paris": (48.8566, 2.3522),
    "Montpellier": (43.6119, 3.8772),
    "München": (48.1351, 11.5820),
    "Roma": (41.9028, 12.4964),
    "Marseille": (43.2965, 5.3698),
    "Strasbourg": (48.5839, 7.7455),
}

villes_secondaires = {
    "Venezia": (45.4408, 12.3155),
    "Toulon": (43.1242, 5.9280),
    "Cannes": (43.5528, 7.0174),
    "Nice": (43.7102, 7.2620),
    "Firenze": (43.7696, 11.2558),
    "Bologna": (44.4949, 11.3426),
    "Salzburg": (47.8095, 13.0550),
    "Villach": (46.6167, 13.8500),
    "Genova": (44.4056, 8.9463),
    "Lucca": (43.8429, 10.5027),
    "Udine": (46.0620, 13.2340),
    "Rapallo": (44.3500, 9.2330),
    "Gérardmer": (48.0727, 6.8990),
    "Troyes": (48.2973, 4.0744),
}

base_offset = 8
max_offset = 10
zoom_factor = 1.2

def haversine(lat1, lon1, lat2, lon2):
    return math.sqrt((lat1 - lat2)**2 + (lon1 - lon2)**2)

offsets = {}
for noms, villes_dict in [('primary', villes_primaires), ('secondary', villes_secondaires)]:
    for nom in villes_dict.keys():
        offsets[nom] = (base_offset, -base_offset)

noms_all = list(villes_primaires.keys()) + list(villes_secondaires.keys())
proximity_thresh = 0.5
for i in range(len(noms_all)):
    for j in range(i+1, len(noms_all)):
        city1, city2 = noms_all[i], noms_all[j]
        lat1, lon1 = villes_primaires.get(city1, villes_secondaires.get(city1))
        lat2, lon2 = villes_primaires.get(city2, villes_secondaires.get(city2))
        dist = haversine(lat1, lon1, lat2, lon2)
        if dist < proximity_thresh:
            offset_val = min(max_offset, (proximity_thresh - dist) / proximity_thresh * max_offset)
            dx = offset_val * zoom_factor
            dy = offset_val * zoom_factor
            offsets[city1] = (-dx, -dy)
            offsets[city2] = (dx, dy)

# Marques des villes primaires (toujours visibles)
for nom, coord in villes_primaires.items():
    folium.CircleMarker(
        location=coord,
        radius=4,
        color='white',
        fill=True,
        fill_color='blue',
        fill_opacity=0.9
    ).add_to(m)

    dx, dy = offsets[nom]
    folium.map.Marker(
        location=coord,
        icon=folium.DivIcon(
            icon_size=(150, 36),
            icon_anchor=(0, 0),
            html=f"""<div class="primary-city" style="font-size:14px; color:white; font-weight:bold;
            text-shadow:1px 1px 2px black;
            transform: translate({dx}px, {dy}px);">{nom}</div>"""
        )
    ).add_to(m)

# Marques des villes secondaires (visibles selon zoom)
for nom, coord in villes_secondaires.items():
    folium.CircleMarker(
        location=coord,
        radius=4,
        color='white',
        fill=True,
        fill_color='red',
        fill_opacity=0.9
    ).add_to(m)

    dx, dy = offsets[nom]
    # Important : display:none by default pour cacher les villes secondaires au chargement
    folium.map.Marker(
        location=coord,
        icon=folium.DivIcon(
            icon_size=(150, 36),
            icon_anchor=(0, 0),
            html=f"""<div class="secondary-city" style="font-size:14px; color:white; font-weight:bold; display:none;
            text-shadow:1px 1px 2px black;
            transform: translate({dx}px, {dy}px);">{nom}</div>"""
        )
    ).add_to(m)

# -------------------------------
# Injection JS gestion visibilité villes secondaires selon zoom
# -------------------------------
min_zoom_to_show_secondary = 9  # Niveau de zoom minimum pour afficher les villes secondaires
map_name = m.get_name()

toggle_js = f"""
function toggleSecondaryCities() {{
    var zoom = {map_name}.getZoom();
    var secondaryElems = document.getElementsByClassName('secondary-city');
    for(var i=0; i<secondaryElems.length; i++) {{
        secondaryElems[i].style.display = (zoom >= {min_zoom_to_show_secondary}) ? 'block' : 'none';
    }}
}}

// Initialiser la visibilité dès la création de la carte
toggleSecondaryCities();

// Ecouter les changements de zoom
{map_name}.on('zoomend', function() {{
    toggleSecondaryCities();
}});
"""

class ZoomToggle(MacroElement):
    def __init__(self, script):
        super().__init__()
        self._template = Template(f"""
        <script>
        {script}
        </script>
        """)

m.get_root().add_child(ZoomToggle(toggle_js))

# -------------------------------
# 6. Sauvegarder
# -------------------------------
output_file = "index.html"
m.save(output_file)
print(f"✅ Carte générée : {output_file}")
# Out:
# ✅ Carte générée : index.html

# %%
import folium
import gpxpy
import glob
import pandas as pd
import matplotlib.colors as colors
import os
import math

# -------------------------------
# 1. Paramètres globaux
# -------------------------------
center_lat = 46
center_lon = 8
zoom_start = 7.1

# -------------------------------
# 2. Définition des voyages
# -------------------------------
voyages = {
    "2025_Montpellier-Munich": {
        "folder": "gpx/2025_Montpellier-Munich",
        "type": "palette",
        "colors": ["#FFD000", "#FF0000"],  # Jaune -> Rouge
        "legend": {
            "Trip name": "Montpellier-Munich",
            "Date": "July-August 2025",
            "Distance": "2200 km",
            "Total D+": "16000 m"
        }
    },
    "2024_Alsace-Paris": {
        "folder": "gpx/2024_Alsace-Paris",
        "type": "fixed",
        "color": "#FFA500",  # Orange fixe
        "legend": {
            "Trip name": "Alsace-Paris",
            "Date": "2024",
            "Distance": "XXX km",
            "Total D+": "XXX m"
        }
    }
}

# -------------------------------
# 3. Créer la carte
# -------------------------------
m = folium.Map(location=[center_lat, center_lon], zoom_start=zoom_start, tiles=None)
folium.TileLayer(
    tiles="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}",
    attr='Tiles © Esri',
    name="ESRI Satellite",
    overlay=False,
    control=True
).add_to(m)

# -------------------------------
# 4. Tracer les GPX avec popup + tooltip (complète)
# -------------------------------
for voyage_name, params in voyages.items():
    folder = params["folder"]
    gpx_files = glob.glob(os.path.join(folder, "*.gpx"))

    # HTML complet de la légende pour tooltip et popup
    legend = params.get("legend", {})
    legend_html = f"""
    <div style="
        background-color: rgba(0,0,0,0.6); 
        color: white; 
        padding: 8px; 
        border-radius: 8px; 
        font-size: 14px; 
        font-weight: bold;
        text-shadow: 1px 1px 2px black;">
        Trip name: {legend.get('Trip name','')}<br>
        Date: {legend.get('Date','')}<br>
        Distance: {legend.get('Distance','')}<br>
        Total D+: {legend.get('Total D+','')}
    </div>
    """

    if params["type"] == "palette":
        txt_path = os.path.join(folder, "D+.txt")
        df = pd.read_csv(txt_path, sep="\t", header=None)
        df = df.rename(columns={0: "GPX", 3: "Difficulte"})
        df["GPX"] = df["GPX"].astype(int)

        cmap = colors.LinearSegmentedColormap.from_list("yellow_red", params["colors"])
        norm = colors.Normalize(vmin=df["Difficulte"].min(), vmax=df["Difficulte"].max())

        def get_color(val):
            rgba = cmap(norm(val))
            return colors.to_hex(rgba)

        for gpx_file in gpx_files:
            filename = os.path.basename(gpx_file)
            try:
                gpx_num = int(os.path.splitext(filename)[0])
                difficulte = df.loc[df["GPX"] == gpx_num, "Difficulte"].values[0]
                color = get_color(difficulte)
            except Exception:
                color = "#FFD000"

            with open(gpx_file, 'r', encoding='utf-8') as f:
                gpx = gpxpy.parse(f)
                for track in gpx.tracks:
                    for segment in track.segments:
                        points = [(p.latitude, p.longitude) for p in segment.points]
                        if points:
                            folium.PolyLine(
                                points,
                                color=color,
                                weight=4,
                                opacity=0.9,
                                popup=folium.Popup(legend_html, max_width=300),
                                tooltip=legend_html
                            ).add_to(m)

    elif params["type"] == "fixed":
        color = params["color"]
        for gpx_file in gpx_files:
            with open(gpx_file, 'r', encoding='utf-8') as f:
                gpx = gpxpy.parse(f)
                for track in gpx.tracks:
                    for segment in track.segments:
                        points = [(p.latitude, p.longitude) for p in segment.points]
                        if points:
                            folium.PolyLine(
                                points,
                                color=color,
                                weight=4,
                                opacity=0.9,
                                popup=folium.Popup(legend_html, max_width=300),
                                tooltip=legend_html
                            ).add_to(m)

# -------------------------------
# 5. Villes principales / secondaires avec offsets et zoom dynamique
# -------------------------------
villes = {
    "Paris": (48.8566, 2.3522),
    "Montpellier": (43.6119, 3.8772),
    "Venezia": (45.4408, 12.3155),
    "Marseille": (43.2965, 5.3698),
    "Toulon": (43.1242, 5.9280),
    "Cannes": (43.5528, 7.0174),
    "Nice": (43.7102, 7.2620),
    "Firenze": (43.7696, 11.2558),
    "Bologna": (44.4949, 11.3426),
    "Salzburg": (47.8095, 13.0550),
    "Villach": (46.6167, 13.8500),
    "Genova": (44.4056, 8.9463),
    "Lucca": (43.8429, 10.5027),
    "Udine": (46.0620, 13.2340),
    "München": (48.1351, 11.5820),
    "Roma": (41.9028, 12.4964),
    "Rapallo": (44.3500, 9.2330),
    "Strasbourg": (48.5839, 7.7455),
    "Gérardmer": (48.0727, 6.8990),
    "Troyes": (48.2973, 4.0744)
}

# Catégorisation
villes_principales = ["Paris", "Montpellier", "München", "Roma", "Strasbourg"]
villes_secondaires = [v for v in villes if v not in villes_principales]

# Offsets
proximity_thresh = 0.5
base_offset = 8
max_offset = 10
zoom_factor = 1.2

def haversine(lat1, lon1, lat2, lon2):
    return math.sqrt((lat1 - lat2)**2 + (lon1 - lon2)**2)

offsets = {nom: (base_offset, -base_offset) for nom in villes.keys()}
noms = list(villes.keys())
for i in range(len(noms)):
    for j in range(i+1, len(noms)):
        city1, city2 = noms[i], noms[j]
        lat1, lon1 = villes[city1]
        lat2, lon2 = villes[city2]
        dist = haversine(lat1, lon1, lat2, lon2)
        if dist < proximity_thresh:
            offset_val = min(max_offset, (proximity_thresh - dist) / proximity_thresh * max_offset)
            dx = offset_val * zoom_factor
            dy = offset_val * zoom_factor
            offsets[city1] = (-dx, -dy)
            offsets[city2] = (dx, dy)

# -------------------------------
# FeatureGroups
# -------------------------------
fg_principales = folium.FeatureGroup(name="Villes principales")
fg_secondaires = folium.FeatureGroup(name="Villes secondaires")

# Villes principales
for nom in villes_principales:
    coord = villes[nom]
    dx, dy = offsets[nom]
    folium.CircleMarker(
        location=coord,
        radius=4,
        color='white',
        fill=True,
        fill_color='blue',
        fill_opacity=0.9
    ).add_to(fg_principales)
    folium.map.Marker(
        location=coord,
        icon=folium.DivIcon(
            icon_size=(150, 36),
            icon_anchor=(0, 0),
            html=f"""<div style="font-size:14px; color:white; font-weight:bold;
                        text-shadow:1px 1px 2px black;
                        transform: translate({dx}px, {dy}px);">{nom}</div>"""
        )
    ).add_to(fg_principales)

# Villes secondaires
for nom in villes_secondaires:
    coord = villes[nom]
    dx, dy = offsets[nom]
    folium.CircleMarker(
        location=coord,
        radius=3,
        color='white',
        fill=True,
        fill_color='green',
        fill_opacity=0.8
    ).add_to(fg_secondaires)
    folium.map.Marker(
        location=coord,
        icon=folium.DivIcon(
            icon_size=(150, 36),
            icon_anchor=(0, 0),
            html=f"""<div style="font-size:12px; color:white; font-weight:bold;
                        text-shadow:1px 1px 2px black;
                        transform: translate({dx}px, {dy}px);">{nom}</div>"""
        )
    ).add_to(fg_secondaires)

fg_principales.add_to(m)
fg_secondaires.add_to(m)

# -------------------------------
# Contrôle de calques
# -------------------------------
folium.LayerControl().add_to(m)

# -------------------------------
# JS pour afficher secondaires uniquement à zoom >= 8
# -------------------------------
js = f"""
var secondairesLayer = {fg_secondaires.get_name()};
function setSecondaryVisibility(){{
    var zoom = map.getZoom();
    if(zoom < 8){{
        map.removeLayer(secondairesLayer);
    }} else {{
        map.addLayer(secondairesLayer);
    }}
}}
map.on('zoomend', setSecondaryVisibility);
setSecondaryVisibility();
"""
m.get_root().html.add_child(folium.Element(f'<script>{js}</script>'))

# -------------------------------
# 6. Sauvegarder
# -------------------------------
output_file = "index.html"
m.save(output_file)
print(f"✅ Carte générée : {output_file}")
# Out:
# ✅ Carte générée : index.html

# %% [markdown]
# ### Le Chat

# %%
import folium
import gpxpy
import glob
import pandas as pd
import matplotlib.colors as colors
import os
import math
from folium import plugins

# -------------------------------
# 1. Global parameters
# -------------------------------
center_lat = 46
center_lon = 8
zoom_start = 7.1

# -------------------------------
# 2. Trips definition
# -------------------------------
voyages = {
    "2025_Montpellier-Munich": {
        "folder": "gpx/2025_Montpellier-Munich",
        "type": "palette",
        "colors": ["#FFD000", "#FF0000"],  # Yellow -> Red
        "legend": {
            "Trip name": "Montpellier-Munich",
            "Date": "July-August 2025",
            "Distance": "2200 km",
            "Total D+": "16000 m"
        }
    },
    "2024_Alsace-Paris": {
        "folder": "gpx/2024_Alsace-Paris",
        "type": "fixed",
        "color": "#FFA500",  # Fixed orange
        "legend": {
            "Trip name": "Alsace-Paris",
            "Date": "2024",
            "Distance": "XXX km",
            "Total D+": "XXX m"
        }
    }
}

# -------------------------------
# 3. Create the map
# -------------------------------
m = folium.Map(location=[center_lat, center_lon], zoom_start=zoom_start, tiles=None)
folium.TileLayer(
    tiles="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}",
    attr='Tiles © Esri',
    name="ESRI Satellite",
    overlay=False,
    control=True
).add_to(m)

# -------------------------------
# 4. Draw GPX with popup + tooltip (complete)
# -------------------------------
for voyage_name, params in voyages.items():
    folder = params["folder"]
    gpx_files = glob.glob(os.path.join(folder, "*.gpx"))
    legend = params.get("legend", {})
    legend_html = f"""
    <div style="
        background-color: rgba(0,0,0,0.6);
        color: white;
        padding: 8px;
        border-radius: 8px;
        font-size: 14px;
        font-weight: bold;
        text-shadow: 1px 1px 2px black;">
        Trip name: {legend.get('Trip name','')}<br>
        Date: {legend.get('Date','')}<br>
        Distance: {legend.get('Distance','')}<br>
        Total D+: {legend.get('Total D+','')}
    </div>
    """
    if params["type"] == "palette":
        txt_path = os.path.join(folder, "D+.txt")
        df = pd.read_csv(txt_path, sep="\t", header=None)
        df = df.rename(columns={0: "GPX", 3: "Difficulte"})
        df["GPX"] = df["GPX"].astype(int)
        cmap = colors.LinearSegmentedColormap.from_list("yellow_red", params["colors"])
        norm = colors.Normalize(vmin=df["Difficulte"].min(), vmax=df["Difficulte"].max())
        def get_color(val):
            rgba = cmap(norm(val))
            return colors.to_hex(rgba)
        for gpx_file in gpx_files:
            filename = os.path.basename(gpx_file)
            try:
                gpx_num = int(os.path.splitext(filename)[0])
                difficulte = df.loc[df["GPX"] == gpx_num, "Difficulte"].values[0]
                color = get_color(difficulte)
            except Exception:
                color = "#FFD000"
            with open(gpx_file, 'r', encoding='utf-8') as f:
                gpx = gpxpy.parse(f)
                for track in gpx.tracks:
                    for segment in track.segments:
                        points = [(p.latitude, p.longitude) for p in segment.points]
                        if points:
                            folium.PolyLine(
                                points,
                                color=color,
                                weight=4,
                                opacity=0.9,
                                popup=folium.Popup(legend_html, max_width=300),
                                tooltip=legend_html
                            ).add_to(m)
    elif params["type"] == "fixed":
        color = params["color"]
        for gpx_file in gpx_files:
            with open(gpx_file, 'r', encoding='utf-8') as f:
                gpx = gpxpy.parse(f)
                for track in gpx.tracks:
                    for segment in track.segments:
                        points = [(p.latitude, p.longitude) for p in segment.points]
                        if points:
                            folium.PolyLine(
                                points,
                                color=color,
                                weight=4,
                                opacity=0.9,
                                popup=folium.Popup(legend_html, max_width=300),
                                tooltip=legend_html
                            ).add_to(m)

# -------------------------------
# 5. Cities with offset and zoom-dependent visibility
# -------------------------------
villes_primaires = {
    "Paris": (48.8566, 2.3522),
    "Montpellier": (43.6119, 3.8772),
    "München": (48.1351, 11.5820),
    "Strasbourg": (48.5839, 7.7455),
    "Roma": (41.9028, 12.4964),
}

villes_secondaires = {
    "Venezia": (45.4408, 12.3155),
    "Marseille": (43.2965, 5.3698),
    "Toulon": (43.1242, 5.9280),
    "Cannes": (43.5528, 7.0174),
    "Nice": (43.7102, 7.2620),
    "Firenze": (43.7696, 11.2558),
    "Bologna": (44.4949, 11.3426),
    "Salzburg": (47.8095, 13.0550),
    "Villach": (46.6167, 13.8500),
    "Genova": (44.4056, 8.9463),
    "Lucca": (43.8429, 10.5027),
    "Udine": (46.0620, 13.2340),
    "Rapallo": (44.3500, 9.2330),
    "Gérardmer": (48.0727, 6.8990),
    "Troyes": (48.2973, 4.0744)
}

proximity_thresh = 0.5
base_offset = 8
max_offset = 10
zoom_factor = 1.2

def haversine(lat1, lon1, lat2, lon2):
    return math.sqrt((lat1 - lat2)**2 + (lon1 - lon2)**2)

# Calculate offsets for all cities
villes = {**villes_primaires, **villes_secondaires}
offsets = {nom: (base_offset, -base_offset) for nom in villes.keys()}
noms = list(villes.keys())
for i in range(len(noms)):
    for j in range(i+1, len(noms)):
        city1, city2 = noms[i], noms[j]
        lat1, lon1 = villes[city1]
        lat2, lon2 = villes[city2]
        dist = haversine(lat1, lon1, lat2, lon2)
        if dist < proximity_thresh:
            offset_val = min(max_offset, (proximity_thresh - dist) / proximity_thresh * max_offset)
            dx = offset_val * zoom_factor
            dy = offset_val * zoom_factor
            offsets[city1] = (-dx, -dy)
            offsets[city2] = (dx, dy)

# Add primary cities (always visible)
for nom, coord in villes_primaires.items():
    dx, dy = offsets[nom]
    folium.Marker(
        location=coord,
        icon=folium.DivIcon(
            icon_size=(150, 36),
            icon_anchor=(0, 0),
            html=f"""<div style="font-size:14px; color:white; font-weight:bold;
                        text-shadow:1px 1px 2px black;
                        transform: translate({dx}px, {dy}px);">{nom}</div>"""
        )
    ).add_to(m)

# Add secondary cities (visible from zoom 9)
for nom, coord in villes_secondaires.items():
    dx, dy = offsets[nom]
    marker = folium.Marker(
        location=coord,
        icon=folium.DivIcon(
            icon_size=(150, 36),
            icon_anchor=(0, 0),
            html=f"""<div style="font-size:14px; color:white; font-weight:bold;
                        text-shadow:1px 1px 2px black;
                        transform: translate({dx}px, {dy}px);">{nom}</div>"""
        )
    )
    # Use JavaScript to show/hide based on zoom
    marker._id = f"marker_{nom}"
    marker.add_to(m)
    m.get_root().html.add_child(folium.Element(f"""
        <script>
            var {marker._id} = document.getElementById('{marker._id}');
            map.on('zoomend', function() {{
                if (map.getZoom() >= 9) {{
                    {marker._id}.style.display = 'block';
                }} else {{
                    {marker._id}.style.display = 'none';
                }}
            }});
            if (map.getZoom() < 9) {{
                {marker._id}.style.display = 'none';
            }}
        </script>
    """))

# -------------------------------
# 6. Save the map
# -------------------------------
output_file = "index.html"
m.save(output_file)
print(f"✅ Map generated: {output_file}")
# Out:
# ✅ Map generated: index.html
